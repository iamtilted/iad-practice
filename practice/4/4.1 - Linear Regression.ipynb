# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# generation of synthetic dataset
N = 100
a = 1
b = 3

x = np.random.uniform(0, 5, N)
noise = np.random.normal(0, .5, N)
y = a * x + b + noise

plt.grid()
plt.scatter(x, y, marker = '.', color = 'r')

# %%
X = x.reshape(-1, 1)

# %%
x # 1d array
# Out:
# array([3.42862967, 2.71824652, 1.3699634 , 4.44756379, 1.64611864,
#        2.0814402 , 4.32833623, 0.63716819, 2.32304873, 0.27361605,
#        1.18947833, 4.92273866, 3.23148126, 1.34463131, 0.1494641 ,
#        2.35834734, 3.09733204, 2.05760096, 3.29545991, 0.61211441,
#        0.59669604, 0.6136709 , 1.05428338, 0.02593834, 3.66604811,
#        1.51157878, 4.97631615, 2.01828412, 4.1480974 , 3.15346162,
#        4.4272659 , 3.27166501, 2.18421385, 1.55403148, 0.61937952,
#        0.24281197, 0.57247523, 0.41027252, 2.06749046, 2.14058782,
#        4.91539402, 0.09749078, 1.20318342, 4.11273889, 4.67444782,
#        0.18038659, 2.37870004, 3.98748847, 1.74896496, 4.67829087,
#        4.58013309, 0.31609644, 0.46337793, 1.19096744, 4.75611223,
#        2.22438696, 1.61374243, 0.54308433, 0.88211937, 3.09099177,
#        2.74591601, 2.57708025, 4.70888445, 0.46297007, 0.59539504,
#        2.65951251, 4.6779909 , 0.44920981, 3.02973708, 4.4284386 ,
#        2.16366189, 3.22010545, 2.63921173, 2.04413234, 4.11693954,
#        0.65505248, 1.32825981, 0.06854945, 4.44899387, 3.38112208,
#        3.06825416, 1.99673935, 0.75702262, 2.97504658, 3.38775854,
#        1.13587478, 4.64952255, 3.76353375, 3.01574443, 0.47260431,
#        1.81285728, 1.02900945, 0.41372008, 4.57140167, 3.70812636,
#        1.83592686, 0.69883468, 3.23879991, 3.48476278, 2.85666688])

# %%
X # array where each row is an array to
# Out:
# array([[3.42862967],
#        [2.71824652],
#        [1.3699634 ],
#        [4.44756379],
#        [1.64611864],
#        [2.0814402 ],
#        [4.32833623],
#        [0.63716819],
#        [2.32304873],
#        [0.27361605],
#        [1.18947833],
#        [4.92273866],
#        [3.23148126],
#        [1.34463131],
#        [0.1494641 ],
#        [2.35834734],
#        [3.09733204],
#        [2.05760096],
#        [3.29545991],
#        [0.61211441],
#        [0.59669604],
#        [0.6136709 ],
#        [1.05428338],
#        [0.02593834],
#        [3.66604811],
#        [1.51157878],
#        [4.97631615],
#        [2.01828412],
#        [4.1480974 ],
#        [3.15346162],
#        [4.4272659 ],
#        [3.27166501],
#        [2.18421385],
#        [1.55403148],
#        [0.61937952],
#        [0.24281197],
#        [0.57247523],
#        [0.41027252],
#        [2.06749046],
#        [2.14058782],
#        [4.91539402],
#        [0.09749078],
#        [1.20318342],
#        [4.11273889],
#        [4.67444782],
#        [0.18038659],
#        [2.37870004],
#        [3.98748847],
#        [1.74896496],
#        [4.67829087],
#        [4.58013309],
#        [0.31609644],
#        [0.46337793],
#        [1.19096744],
#        [4.75611223],
#        [2.22438696],
#        [1.61374243],
#        [0.54308433],
#        [0.88211937],
#        [3.09099177],
#        [2.74591601],
#        [2.57708025],
#        [4.70888445],
#        [0.46297007],
#        [0.59539504],
#        [2.65951251],
#        [4.6779909 ],
#        [0.44920981],
#        [3.02973708],
#        [4.4284386 ],
#        [2.16366189],
#        [3.22010545],
#        [2.63921173],
#        [2.04413234],
#        [4.11693954],
#        [0.65505248],
#        [1.32825981],
#        [0.06854945],
#        [4.44899387],
#        [3.38112208],
#        [3.06825416],
#        [1.99673935],
#        [0.75702262],
#        [2.97504658],
#        [3.38775854],
#        [1.13587478],
#        [4.64952255],
#        [3.76353375],
#        [3.01574443],
#        [0.47260431],
#        [1.81285728],
#        [1.02900945],
#        [0.41372008],
#        [4.57140167],
#        [3.70812636],
#        [1.83592686],
#        [0.69883468],
#        [3.23879991],
#        [3.48476278],
#        [2.85666688]])

# %%
# a * x + b = y

model = LinearRegression()
model.fit(X, y)
model
# Out:
# LinearRegression()

# %%
a_found = model.coef_[0]
b_found = model.intercept_

# %%
a_found
# Out:
# np.float64(0.9553571592817393)

# %%
b_found
# Out:
# np.float64(3.063644227777827)
