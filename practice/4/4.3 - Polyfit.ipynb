# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import SGDRegressor
from sklearn.pipeline import make_pipeline

# %%
# дані
N = 100
x = np.linspace(-3, 3, N)  # змінив діапазон x
noise = np.random.normal(0, 1, N)  # збільшив шум
y0 = 2*x**4 - x**2 + 2*x + 3  # змінив коефіцієнти функції
y = y0 + noise

# %%
# polyfit
coef = np.polyfit(x, y, deg=4)
y_fit = np.polyval(coef, x)
coef # c4, c3, c2, c1, c0
# Out:
# array([ 2.00149852, -0.00782613, -1.06670385,  2.0145331 ,  3.13239268])

# %%
# display
plt.grid()
plt.plot(x, y0, "b", label="Початкова функція")
plt.scatter(x, y, color="g", marker=".", label="Дані з шумом", alpha=0.6)
plt.plot(x, y_fit, label="Апроксимація", color="r")
plt.legend()
